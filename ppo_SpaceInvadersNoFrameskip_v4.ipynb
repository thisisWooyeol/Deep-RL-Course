# %% [markdown]
# <a href="https://colab.research.google.com/github/thisisWooyeol/Deep-RL-Course/blob/master/ppo_SpaceInvadersNoFrameskip_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# For now we install this update of RL-Baselines3 Zoo
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo (to revision update/hf) to /tmp/pip-req-build-61l_f0c_
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-61l_f0c_
#   Running command git checkout -b update/hf --track origin/update/hf
#   Switched to a new branch 'update/hf'
#   Branch 'update/hf' set up to track remote branch 'update/hf' from 'origin'.
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 7dcbff7e74e7a12c052452181ff353a4dbed313a
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3-contrib>=2.0.0a9 (from rl_zoo3==2.0.0a9)
#   Downloading sb3_contrib-2.2.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting gym==0.26.2 (from rl_zoo3==2.0.0a9)
#   Using cached gym-0.26.2-py3-none-any.whl
# Collecting huggingface-sb3>=2.2.1 (from rl_zoo3==2.0.0a9)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tqdm (from rl_zoo3==2.0.0a9)
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.5 MB/s eta 0:00:00
# Collecting rich (from rl_zoo3==2.0.0a9)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting optuna (from rl_zoo3==2.0.0a9)
#   Downloading optuna-3.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting pyyaml>=5.1 (from rl_zoo3==2.0.0a9)
#   Downloading PyYAML-6.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting pytablewriter~=0.64 (from rl_zoo3==2.0.0a9)
#   Downloading pytablewriter-0.64.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (1.24.1)
# Collecting cloudpickle>=1.2.0 (from gym==0.26.2->rl_zoo3==2.0.0a9)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting gym-notices>=0.0.4 (from gym==0.26.2->rl_zoo3==2.0.0a9)
#   Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Collecting huggingface-hub~=0.8 (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9)
#   Downloading huggingface_hub-0.20.1-py3-none-any.whl.metadata (12 kB)
# Collecting wasabi (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9)
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: setuptools>=38.3.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (68.2.2)
# Collecting DataProperty<2,>=0.55.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading DataProperty-1.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathvalidate<3,>=2.3.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting tabledata<2,>=1.3.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading tabledata-1.3.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading tcolorpy-0.1.4-py3-none-any.whl.metadata (5.7 kB)
# Collecting typepy<2,>=1.2.0 (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading typepy-1.3.2-py3-none-any.whl.metadata (9.3 kB)
# Collecting stable-baselines3<3.0,>=2.2.1 (from sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting alembic>=1.5.0 (from optuna->rl_zoo3==2.0.0a9)
#   Downloading alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna->rl_zoo3==2.0.0a9)
#   Downloading colorlog-6.8.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from optuna->rl_zoo3==2.0.0a9) (23.2)
# Collecting sqlalchemy>=1.3.0 (from optuna->rl_zoo3==2.0.0a9)
#   Downloading SQLAlchemy-2.0.24-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->rl_zoo3==2.0.0a9)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from rich->rl_zoo3==2.0.0a9) (2.17.2)
# Collecting Mako (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9)
#   Downloading Mako-1.3.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (4.9.0)
# Requirement already satisfied: filelock in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.9.0)
# Collecting fsspec>=2023.5.0 (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9)
#   Downloading fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: requests in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.28.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.0.0a9)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting chardet<6,>=3.0.4 (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna->rl_zoo3==2.0.0a9)
#   Downloading greenlet-3.0.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.13 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.1.2+cu118)
# Collecting pandas (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading pandas-2.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting matplotlib (from stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading matplotlib-3.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2.8.2)
# Collecting pytz>=2018.9 (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: six>=1.5 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: sympy in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.12)
# Requirement already satisfied: networkx in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.0)
# Requirement already satisfied: jinja2 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.1.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (2.1.3)
# Collecting contourpy>=1.0.1 (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading contourpy-1.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading fonttools-4.47.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 18.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: pillow>=8 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (9.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting tzdata>=2022.1 (from pandas->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from sympy->torch>=1.13->stable-baselines3<3.0,>=2.2.1->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.3.0)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading PyYAML-6.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.7/757.7 kB 28.0 MB/s eta 0:00:00
# Downloading sb3_contrib-2.2.1-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 14.4 MB/s eta 0:00:00
# Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 50.2 MB/s eta 0:00:00
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 36.4 MB/s eta 0:00:00
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 13.5 MB/s eta 0:00:00
# Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 33.9 MB/s eta 0:00:00
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Downloading huggingface_hub-0.20.1-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.1/330.1 kB 41.1 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 14.6 MB/s eta 0:00:00
# Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Downloading SQLAlchemy-2.0.24-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 84.7 MB/s eta 0:00:00:00:01
# Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 28.1 MB/s eta 0:00:00
# Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 29.3 MB/s eta 0:00:00
# Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 27.1 MB/s eta 0:00:00
# Downloading greenlet-3.0.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (620 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.0/620.0 kB 62.5 MB/s eta 0:00:00
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 67.5 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 60.0 MB/s eta 0:00:00
# Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 13.8 MB/s eta 0:00:00
# Downloading matplotlib-3.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 113.4 MB/s eta 0:00:0000:010:01
# Downloading pandas-2.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 78.2 MB/s eta 0:00:00:00:0100:01
# Downloading contourpy-1.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 40.0 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.47.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 122.6 MB/s eta 0:00:0000:01
# Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 87.5 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 17.2 MB/s eta 0:00:00
# Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 42.3 MB/s eta 0:00:00
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.0.0a9-py3-none-any.whl size=76403 sha256=e1bb762a4173c68ca7aded517926ac9c12b6de203cf758c96af911646d20355d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s7o2_oka/wheels/88/bc/57/4011c512d8515b0fa029a76996b95391477d172f7698c9e186
# Successfully built rl_zoo3
# Installing collected packages: pytz, gym-notices, farama-notifications, wasabi, tzdata, tqdm, tcolorpy, pyyaml, pyparsing, pathvalidate, mdurl, Mako, kiwisolver, greenlet, fsspec, fonttools, cycler, contourpy, colorlog, cloudpickle, chardet, sqlalchemy, pandas, mbstrdecoder, matplotlib, markdown-it-py, huggingface-hub, gymnasium, gym, typepy, stable-baselines3, rich, huggingface-sb3, alembic, sb3-contrib, optuna, DataProperty, tabledata, pytablewriter, rl_zoo3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
# Successfully installed DataProperty-1.0.1 Mako-1.3.0 alembic-1.13.1 chardet-5.2.0 cloudpickle-3.0.0 colorlog-6.8.0 contourpy-1.2.0 cycler-0.12.1 farama-notifications-0.0.4 fonttools-4.47.0 fsspec-2023.12.2 greenlet-3.0.3 gym-0.26.2 gym-notices-0.0.8 gymnasium-0.29.1 huggingface-hub-0.20.1 huggingface-sb3-3.0 kiwisolver-1.4.5 markdown-it-py-3.0.0 matplotlib-3.8.2 mbstrdecoder-1.1.3 mdurl-0.1.2 optuna-3.5.0 pandas-2.1.4 pathvalidate-2.5.2 pyparsing-3.1.1 pytablewriter-0.64.2 pytz-2023.3.post1 pyyaml-6.0.1 rich-13.7.0 rl_zoo3-2.0.0a9 sb3-contrib-2.2.1 sqlalchemy-2.0.24 stable-baselines3-2.2.1 tabledata-1.3.3 tcolorpy-0.1.4 tqdm-4.66.1 typepy-1.3.2 tzdata-2023.4 wasabi-1.1.2

# %% [markdown]
# IF AND ONLY IF THE VERSION ABOVE DOES NOT EXIST ANYMORE. UNCOMMENT AND INSTALL THE ONE BELOW

# %%
#!pip install rl_zoo3==2.0.0a9

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from gymnasium[atari]) (1.24.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from gymnasium[atari]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from gymnasium[atari]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from gymnasium[atari]) (0.0.4)
# Collecting shimmy<1.0,>=0.1.0 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari])
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari])
#   Downloading ale_py-0.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 22.8 MB/s eta 0:00:0000:010:01
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari])
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Installing collected packages: importlib-resources, shimmy, ale-py
# Successfully installed ale-py-0.8.1 importlib-resources-6.1.1 shimmy-0.2.1
# Requirement already satisfied: gymnasium[accept-rom-license] in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from gymnasium[accept-rom-license]) (1.24.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from gymnasium[accept-rom-license]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from gymnasium[accept-rom-license]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Collecting autorom~=0.4.2 (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license])
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Collecting click (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license])
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: requests in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2.28.1)
# Requirement already satisfied: tqdm in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (4.66.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license])
#   Using cached AutoROM.accept_rom_license-0.6.1-py3-none-any.whl
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2022.12.7)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: click, AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2 click-8.1.7

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c config/dqn.yaml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 2765099948
# Loading hyperparameters from: config/dqn.yaml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 512),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.98e+03 |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 670      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 884      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 688      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.77e+03 |
# |    ep_rew_mean      | 82.5     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 705      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1724     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 728      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2548     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 735      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 98.1     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 739      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3626     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 123      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 755      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4990     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 755      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5418     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 757      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 6220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 123      |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 756      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 6887     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 755      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 7597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 756      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 756      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 756      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 756      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 9579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 758      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 10378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 759      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 11136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 759      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 11849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 760      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 12673    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 760      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 13217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 761      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 13869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 762      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 14655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 762      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 15303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 762      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 16055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 763      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 16650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 764      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 17655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 763      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 18192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 763      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19014    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 763      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 19627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 764      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 20452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 764      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 21156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 764      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 21676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 764      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 22228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 764      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 23034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 764      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 23456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 764      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 24054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 764      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 24491    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=143.00 +/- 49.05
# Episode length: 2376.20 +/- 310.19
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.38e+03 |
# |    mean_reward      | 143      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.752    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 648      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 25094    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 651      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 25956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 653      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 26474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 655      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 27107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 657      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 27595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.72     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 659      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 28238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 660      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 28780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 661      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 29165    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 663      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 29644    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.698    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 666      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 30502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 668      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 31425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.683    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 670      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 32055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 670      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 32611    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 672      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 33432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 673      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 33943    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.659    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 674      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 34408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.654    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 675      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 34981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 676      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 35453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.642    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 677      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 36115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 677      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 36460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 679      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 37297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.624    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 681      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 38028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 682      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 38439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 683      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 39030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.608    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 684      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 39569    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.6      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 686      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 40387    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 687      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 41213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.583    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 689      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 42104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 690      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 42780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.565    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 692      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 43919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.561    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 693      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 44294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 694      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 45082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 694      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 45512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 695      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 46066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.537    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 696      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 46809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.531    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 697      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 47380    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 698      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 47871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.518    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 699      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 48655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.513    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 699      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 49213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 700      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 49790    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=167.00 +/- 35.58
# Episode length: 2433.40 +/- 255.76
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.43e+03 |
# |    mean_reward      | 167      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 655      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 50252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 656      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 50891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 658      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 51756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 659      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 52385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 660      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 52898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.47     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 661      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 53503    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 662      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 54255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 664      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 55303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.448    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 664      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 55766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 665      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 56731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 666      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 57581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.425    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 667      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 58047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 667      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 58525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 668      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 59287    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 669      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 59776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.401    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 670      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 60521    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 671      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 61083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.389    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 672      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 61755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.383    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 673      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 62289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.376    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 674      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 62998    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 675      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 63748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.365    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 675      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 64155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.36     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 676      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 64600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 676      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 65067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.349    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 677      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 65796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 679      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 66770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 679      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 67391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 680      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 67811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 680      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 68418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.315    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 681      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 69220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.311    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 682      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 69623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.304    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 683      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 70285    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 683      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 70798    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 684      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 71457    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.287    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 684      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 72065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 685      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 72888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 686      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 73765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 687      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 74406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 687      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 74986    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=186.00 +/- 12.00
# Episode length: 2510.60 +/- 52.14
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.51e+03 |
# |    mean_reward      | 186      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.251    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 654      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 75618    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.246    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 655      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 76208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 131      |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 218057   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4276     |
# |    fps              | 142      |
# |    time_elapsed     | 6837     |
# |    total_timesteps  | 973484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0447   |
# |    n_updates        | 218370   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3e+03    |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4280     |
# |    fps              | 142      |
# |    time_elapsed     | 6843     |
# |    total_timesteps  | 974225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 218556   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=425.00 +/- 152.51
# Episode length: 3570.60 +/- 1034.21
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.57e+03 |
# |    mean_reward      | 425      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.05     |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4284     |
# |    fps              | 142      |
# |    time_elapsed     | 6861     |
# |    total_timesteps  | 975448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 218861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.96e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4288     |
# |    fps              | 142      |
# |    time_elapsed     | 6867     |
# |    total_timesteps  | 976245   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 219061   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.97e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4292     |
# |    fps              | 142      |
# |    time_elapsed     | 6875     |
# |    total_timesteps  | 977220   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0434   |
# |    n_updates        | 219304   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4296     |
# |    fps              | 142      |
# |    time_elapsed     | 6885     |
# |    total_timesteps  | 978486   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.052    |
# |    n_updates        | 219621   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4300     |
# |    fps              | 142      |
# |    time_elapsed     | 6891     |
# |    total_timesteps  | 979282   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0692   |
# |    n_updates        | 219820   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.97e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4304     |
# |    fps              | 142      |
# |    time_elapsed     | 6899     |
# |    total_timesteps  | 980308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0484   |
# |    n_updates        | 220076   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.97e+03 |
# |    ep_rew_mean      | 401      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4308     |
# |    fps              | 142      |
# |    time_elapsed     | 6907     |
# |    total_timesteps  | 981277   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0442   |
# |    n_updates        | 220319   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.95e+03 |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4312     |
# |    fps              | 142      |
# |    time_elapsed     | 6911     |
# |    total_timesteps  | 981858   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 220464   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4316     |
# |    fps              | 142      |
# |    time_elapsed     | 6916     |
# |    total_timesteps  | 982532   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0725   |
# |    n_updates        | 220632   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4320     |
# |    fps              | 142      |
# |    time_elapsed     | 6924     |
# |    total_timesteps  | 983548   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 220886   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92e+03 |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4324     |
# |    fps              | 142      |
# |    time_elapsed     | 6934     |
# |    total_timesteps  | 984840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0493   |
# |    n_updates        | 221209   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4328     |
# |    fps              | 142      |
# |    time_elapsed     | 6940     |
# |    total_timesteps  | 985542   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0559   |
# |    n_updates        | 221385   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4332     |
# |    fps              | 141      |
# |    time_elapsed     | 6947     |
# |    total_timesteps  | 986514   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 221628   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4336     |
# |    fps              | 141      |
# |    time_elapsed     | 6955     |
# |    total_timesteps  | 987475   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0513   |
# |    n_updates        | 221868   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4340     |
# |    fps              | 141      |
# |    time_elapsed     | 6960     |
# |    total_timesteps  | 988115   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 222028   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4344     |
# |    fps              | 141      |
# |    time_elapsed     | 6967     |
# |    total_timesteps  | 989084   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.064    |
# |    n_updates        | 222270   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.93e+03 |
# |    ep_rew_mean      | 401      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4348     |
# |    fps              | 141      |
# |    time_elapsed     | 6976     |
# |    total_timesteps  | 990382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 222595   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4352     |
# |    fps              | 141      |
# |    time_elapsed     | 6982     |
# |    total_timesteps  | 991246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 222811   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92e+03 |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4356     |
# |    fps              | 141      |
# |    time_elapsed     | 6989     |
# |    total_timesteps  | 992280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0355   |
# |    n_updates        | 223069   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4360     |
# |    fps              | 141      |
# |    time_elapsed     | 6996     |
# |    total_timesteps  | 993332   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0468   |
# |    n_updates        | 223332   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4364     |
# |    fps              | 141      |
# |    time_elapsed     | 7003     |
# |    total_timesteps  | 994221   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0429   |
# |    n_updates        | 223555   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4368     |
# |    fps              | 141      |
# |    time_elapsed     | 7009     |
# |    total_timesteps  | 995166   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0519   |
# |    n_updates        | 223791   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 401      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4372     |
# |    fps              | 141      |
# |    time_elapsed     | 7017     |
# |    total_timesteps  | 996184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0403   |
# |    n_updates        | 224045   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.92e+03 |
# |    ep_rew_mean      | 401      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4376     |
# |    fps              | 141      |
# |    time_elapsed     | 7025     |
# |    total_timesteps  | 997459   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0361   |
# |    n_updates        | 224364   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.93e+03 |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4380     |
# |    fps              | 141      |
# |    time_elapsed     | 7034     |
# |    total_timesteps  | 998666   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0484   |
# |    n_updates        | 224666   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4384     |
# |    fps              | 141      |
# |    time_elapsed     | 7042     |
# |    total_timesteps  | 999875   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 224968   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=329.00 +/- 98.41
# Episode length: 2556.80 +/- 569.70
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.56e+03 |
# |    mean_reward      | 329      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=4
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_4/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 330.00
# Atari Episode Length 2573
# Atari Episode Score: 275.00
# Atari Episode Length 3089
# Atari Episode Score: 245.00
# Atari Episode Length 1929
# Atari Episode Score: 420.00
# Atari Episode Length 3187
# Atari Episode Score: 450.00
# Atari Episode Length 3135
# Atari Episode Score: 365.00
# Atari Episode Length 2552
# Atari Episode Score: 180.00
# Atari Episode Length 2775

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga thisiswooyeol -f logs/
# Out:
# Loading latest experiment, id=4
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_4/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to thisiswooyeol/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/thisiswooyeol/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/thisiswooyeol/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Saving video to /tmp/tmpcbzdhkm3/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpcbzdhkm3/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpcbzdhkm3/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpcbzdhkm3/-step-0-to-step-1000.mp4
# sh: 1: ffmpeg: not found
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0%| | 1.00/26.0M [00:00<?, ?B
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0%| | 1.00/1
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth:   0%| | 1.00/
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0%| | 1.00/12.9M [00:0
#
#
#
# Upload file train_eval_metrics.zip:   0%|           | 1.00/38.8k [00:00<?, ?B/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 15.3MB [00:02, 8.00MB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 30.5MB [00:04, 8.00MB/s]       To https://huggingface.co/thisiswooyeol/dqn-SpaceInvadersNoFrameskip-v4
#    b7e60ca..2ab9973  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/thisiswooyeol/dqn-SpaceInvadersNoFrameskip-v4
#    b7e60ca..2ab9973  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|█| 26.0M/26.0M [00:05<00:0
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|█| 12.9M/
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|█| 864/8
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|█| 864/8
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|█| 12.9M/12.9M [00:
#
#
#
#
# Upload file train_eval_metrics.zip: 100%|██| 38.8k/38.8k [00:05<00:00, 3.20MB/s]
#
#
#
# Upload file train_eval_metrics.zip: 100%|██| 38.8k/38.8k [00:05<00:00, 7.94kB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/thisiswooyeol/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Out:
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# dqn-BeamRiderNoFrameskip-v4.zip: 100%|█████| 27.2M/27.2M [00:02<00:00, 9.94MB/s]
# config.yml: 100%|██████████████████████████████| 548/548 [00:00<00:00, 3.57MB/s]
# No normalization file
# args.yml: 100%|████████████████████████████████| 887/887 [00:00<00:00, 5.59MB/s]
# env_kwargs.yml: 100%|████████████████████████| 3.00/3.00 [00:00<00:00, 21.1kB/s]
# train_eval_metrics.zip: 100%|█████████████████| 244k/244k [00:00<00:00, 417kB/s]
# Saving to rl_trained/dqn/BeamRiderNoFrameskip-v4_1

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render
# Out:
# Loading latest experiment, id=1
# Loading rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:166: UserWarning: Could not deserialize object exploration_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code expected at least 16 arguments, got 15
#   warnings.warn(
# /home/wooyeol0519/anaconda3/envs/deep-rl/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# Atari Episode Score: 3028.00
# Atari Episode Length 14816

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
